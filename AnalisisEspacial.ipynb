# %% [markdown]
# <a href="https://colab.research.google.com/github/d4nd14z/DataAnalytics/blob/main/AnalisisEspacial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Análisis Espacial**

# %%
# !pip install geopandas

# %%
import geopandas as gpd

gdf = gpd.read_file("/content/drive/MyDrive/Universidad de La Salle/Análisis Espacial/data/DAILoc.shp")
gdf.plot()
# Out:
# <Axes: >

# %%
gdf = gpd.read_file("/content/drive/MyDrive/Universidad de La Salle/Análisis Espacial/data/DAISCAT.shp")
gdf.plot()
# Out:
# <Axes: >

# %%
gdf = gpd.read_file("/content/drive/MyDrive/Universidad de La Salle/Análisis Espacial/data/DAIUPZ.shp")
gdf.plot()
# Out:
# <Axes: >
